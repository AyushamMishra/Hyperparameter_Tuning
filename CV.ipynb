# %% [markdown]
# <a href="https://colab.research.google.com/github/AyushamMishra/Hyperparameter_Tuning/blob/main/CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hyperparameter tuning using Grid Search CV

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.value_counts('species')
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
X=df.drop('species',axis=1)
y=df['species']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model=KNeighborsClassifier(n_neighbors=3)

# %%
knn_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn_model.score(X_test,y_test)
# Out:
# 1.0

# %%
from sklearn.svm import SVC
svm_model=SVC(gamma='auto')

# %%
svm_model.fit(X_train,y_train)
# Out:
# SVC(gamma='auto')

# %%
svm_model.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# ## Lets use grid search cv

# %%
from sklearn.model_selection import GridSearchCV

# %%
classifier=GridSearchCV(svm_model,{
    'C':[1,10,20,30],'kernel':['rbf','linear']
},cv=5,return_train_score=False)

# %%
classifier.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['rbf', 'linear']})

# %%
import pandas as pd

result = pd.DataFrame(classifier.cv_results_)
result[['param_C', 'param_kernel', 'mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667
# 6       30          rbf         0.960000
# 7       30       linear         0.960000

# %% [markdown]
# ## Hence the grid search cross validation removes overfitting of earlier svm model

# %% [markdown]
# ## Applying grid search cv on KNN model

# %%
knn_classifier = GridSearchCV(
    knn_model,
    {
        'n_neighbors': [3, 5, 7, 9, 13, 15, 17, 25],
        'weights': ['uniform', 'distance'],
        'metric': ['euclidean', 'manhattan', 'minkowski']
    },
    cv=5,
    return_train_score=False,
    n_jobs=-1
)

# %%
knn_classifier.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(n_neighbors=3), n_jobs=-1,
#              param_grid={'metric': ['euclidean', 'manhattan', 'minkowski'],
#                          'n_neighbors': [3, 5, 7, 9, 13, 15, 17, 25],
#                          'weights': ['uniform', 'distance']})

# %%
knn_result = pd.DataFrame(knn_classifier.cv_results_)
knn_result
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_metric  \
# 0        0.006034      0.002190         0.006374        0.001262    euclidean
# 1        0.004746      0.001134         0.004908        0.001347    euclidean
# 2        0.004456      0.001453         0.005890        0.001379    euclidean
# 3        0.003541      0.000149         0.004224        0.000930    euclidean
# 4        0.003879      0.000801         0.005797        0.001713    euclidean
# 5        0.004185      0.001113         0.004253        0.000836    euclidean
# 6        0.004253      0.001679         0.005360        0.000953    euclidean
# 7        0.003331      0.000073         0.003816        0.000156    euclidean
# 8        0.004293      0.001499         0.005596        0.001432    euclidean
# 9        0.003439      0.000223         0.004616        0.001563    euclidean
# 10       0.003581      0.000273         0.005452        0.000910    euclidean
# 11       0.004307      0.001495         0.004549        0.001326    euclidean
# 12       0.003425      0.000092         0.004906        0.000188    euclidean
# 13       0.003321      0.000123         0.004266        0.000975    euclidean
# 14       0.004155      0.001476         0.005212        0.000579    euclidean
# 15       0.003451      0.000073         0.004171        0.000641    euclidean
# 16       0.003440      0.000237         0.004840        0.000143    manhattan
# 17       0.003633      0.000169         0.004211        0.000476    manhattan
# 18       0.003795      0.000355         0.005201        0.000253    manhattan
# 19       0.003573      0.000231         0.003974        0.000166    manhattan
# 20       0.005021      0.001545         0.007099        0.002993    manhattan
# 21       0.003582      0.000167         0.003900        0.000138    manhattan
# 22       0.003660      0.000239         0.004885        0.000260    manhattan
# 23       0.003615      0.000312         0.004285        0.000527    manhattan
# 24       0.004218      0.000539         0.005475        0.000424    manhattan
# 25       0.003583      0.000412         0.003997        0.000259    manhattan
# 26       0.007302      0.002545         0.010973        0.004286    manhattan
# 27       0.003409      0.000122         0.003912        0.000177    manhattan
# 28       0.003722      0.000185         0.005650        0.001217    manhattan
# 29       0.003725      0.000321         0.004049        0.000252    manhattan
# 30       0.003456      0.000198         0.004974        0.000104    manhattan
# 31       0.003378      0.000102         0.003828        0.000095    manhattan
# 32       0.003443      0.000063         0.004878        0.000223    minkowski
# 33       0.003327      0.000073         0.003738        0.000286    minkowski
# 34       0.003483      0.000236         0.004756        0.000079    minkowski
# 35       0.003479      0.000306         0.003777        0.000162    minkowski
# 36       0.003477      0.000135         0.004829        0.000094    minkowski
# 37       0.003979      0.001329         0.003692        0.000040    minkowski
# 38       0.005333      0.000935         0.006538        0.001066    minkowski
# 39       0.005197      0.000878         0.004518        0.001130    minkowski
# 40       0.005089      0.001016         0.006113        0.000830    minkowski
# 41       0.003737      0.000189         0.004025        0.000219    minkowski
# 42       0.003584      0.000091         0.004977        0.000157    minkowski
# 43       0.003516      0.000127         0.004551        0.001509    minkowski
# 44       0.003816      0.000524         0.004935        0.000130    minkowski
# 45       0.003955      0.000868         0.004250        0.000819    minkowski
# 46       0.004361      0.001251         0.005475        0.000931    minkowski
# 47       0.003862      0.000642         0.003871        0.000984    minkowski
#
#     param_n_neighbors param_weights  \
# 0                   3       uniform
# 1                   3      distance
# 2                   5       uniform
# 3                   5      distance
# 4                   7       uniform
# 5                   7      distance
# 6                   9       uniform
# 7                   9      distance
# 8                  13       uniform
# 9                  13      distance
# 10                 15       uniform
# 11                 15      distance
# 12                 17       uniform
# 13                 17      distance
# 14                 25       uniform
# 15                 25      distance
# 16                  3       uniform
# 17                  3      distance
# 18                  5       uniform
# 19                  5      distance
# 20                  7       uniform
# 21                  7      distance
# 22                  9       uniform
# 23                  9      distance
# 24                 13       uniform
# 25                 13      distance
# 26                 15       uniform
# 27                 15      distance
# 28                 17       uniform
# 29                 17      distance
# 30                 25       uniform
# 31                 25      distance
# 32                  3       uniform
# 33                  3      distance
# 34                  5       uniform
# 35                  5      distance
# 36                  7       uniform
# 37                  7      distance
# 38                  9       uniform
# 39                  9      distance
# 40                 13       uniform
# 41                 13      distance
# 42                 15       uniform
# 43                 15      distance
# 44                 17       uniform
# 45                 17      distance
# 46                 25       uniform
# 47                 25      distance
#
#                                                params  split0_test_score  \
# 0   {'metric': 'euclidean', 'n_neighbors': 3, 'wei...           0.958333
# 1   {'metric': 'euclidean', 'n_neighbors': 3, 'wei...           0.958333
# 2   {'metric': 'euclidean', 'n_neighbors': 5, 'wei...           0.958333
# 3   {'metric': 'euclidean', 'n_neighbors': 5, 'wei...           0.958333
# 4   {'metric': 'euclidean', 'n_neighbors': 7, 'wei...           0.958333
# 5   {'metric': 'euclidean', 'n_neighbors': 7, 'wei...           0.958333
# 6   {'metric': 'euclidean', 'n_neighbors': 9, 'wei...           0.958333
# 7   {'metric': 'euclidean', 'n_neighbors': 9, 'wei...           0.958333
# 8   {'metric': 'euclidean', 'n_neighbors': 13, 'we...           1.000000
# 9   {'metric': 'euclidean', 'n_neighbors': 13, 'we...           1.000000
# 10  {'metric': 'euclidean', 'n_neighbors': 15, 'we...           1.000000
# 11  {'metric': 'euclidean', 'n_neighbors': 15, 'we...           1.000000
# 12  {'metric': 'euclidean', 'n_neighbors': 17, 'we...           1.000000
# 13  {'metric': 'euclidean', 'n_neighbors': 17, 'we...           1.000000
# 14  {'metric': 'euclidean', 'n_neighbors': 25, 'we...           1.000000
# 15  {'metric': 'euclidean', 'n_neighbors': 25, 'we...           1.000000
# 16  {'metric': 'manhattan', 'n_neighbors': 3, 'wei...           0.958333
# 17  {'metric': 'manhattan', 'n_neighbors': 3, 'wei...           0.958333
# 18  {'metric': 'manhattan', 'n_neighbors': 5, 'wei...           0.958333
# 19  {'metric': 'manhattan', 'n_neighbors': 5, 'wei...           0.958333
# 20  {'metric': 'manhattan', 'n_neighbors': 7, 'wei...           0.958333
# 21  {'metric': 'manhattan', 'n_neighbors': 7, 'wei...           0.958333
# 22  {'metric': 'manhattan', 'n_neighbors': 9, 'wei...           0.958333
# 23  {'metric': 'manhattan', 'n_neighbors': 9, 'wei...           0.958333
# 24  {'metric': 'manhattan', 'n_neighbors': 13, 'we...           1.000000
# 25  {'metric': 'manhattan', 'n_neighbors': 13, 'we...           1.000000
# 26  {'metric': 'manhattan', 'n_neighbors': 15, 'we...           1.000000
# 27  {'metric': 'manhattan', 'n_neighbors': 15, 'we...           1.000000
# 28  {'metric': 'manhattan', 'n_neighbors': 17, 'we...           1.000000
# 29  {'metric': 'manhattan', 'n_neighbors': 17, 'we...           1.000000
# 30  {'metric': 'manhattan', 'n_neighbors': 25, 'we...           1.000000
# 31  {'metric': 'manhattan', 'n_neighbors': 25, 'we...           1.000000
# 32  {'metric': 'minkowski', 'n_neighbors': 3, 'wei...           0.958333
# 33  {'metric': 'minkowski', 'n_neighbors': 3, 'wei...           0.958333
# 34  {'metric': 'minkowski', 'n_neighbors': 5, 'wei...           0.958333
# 35  {'metric': 'minkowski', 'n_neighbors': 5, 'wei...           0.958333
# 36  {'metric': 'minkowski', 'n_neighbors': 7, 'wei...           0.958333
# 37  {'metric': 'minkowski', 'n_neighbors': 7, 'wei...           0.958333
# 38  {'metric': 'minkowski', 'n_neighbors': 9, 'wei...           0.958333
# 39  {'metric': 'minkowski', 'n_neighbors': 9, 'wei...           0.958333
# 40  {'metric': 'minkowski', 'n_neighbors': 13, 'we...           1.000000
# 41  {'metric': 'minkowski', 'n_neighbors': 13, 'we...           1.000000
# 42  {'metric': 'minkowski', 'n_neighbors': 15, 'we...           1.000000
# 43  {'metric': 'minkowski', 'n_neighbors': 15, 'we...           1.000000
# 44  {'metric': 'minkowski', 'n_neighbors': 17, 'we...           1.000000
# 45  {'metric': 'minkowski', 'n_neighbors': 17, 'we...           1.000000
# 46  {'metric': 'minkowski', 'n_neighbors': 25, 'we...           1.000000
# 47  {'metric': 'minkowski', 'n_neighbors': 25, 'we...           1.000000
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            1.000000           0.875000                1.0
# 1            1.000000           0.875000                1.0
# 2            0.958333           0.833333                1.0
# 3            0.958333           0.833333                1.0
# 4            0.958333           0.833333                1.0
# 5            0.958333           0.833333                1.0
# 6            0.916667           0.833333                1.0
# 7            0.958333           0.833333                1.0
# 8            0.916667           0.833333                1.0
# 9            0.958333           0.833333                1.0
# 10           0.916667           0.833333                1.0
# 11           0.958333           0.833333                1.0
# 12           0.916667           0.833333                1.0
# 13           0.958333           0.833333                1.0
# 14           0.916667           0.833333                1.0
# 15           0.958333           0.833333                1.0
# 16           1.000000           0.875000                1.0
# 17           1.000000           0.875000                1.0
# 18           0.958333           0.833333                1.0
# 19           0.958333           0.833333                1.0
# 20           0.958333           0.833333                1.0
# 21           0.958333           0.833333                1.0
# 22           0.958333           0.833333                1.0
# 23           0.958333           0.833333                1.0
# 24           0.958333           0.833333                1.0
# 25           0.958333           0.833333                1.0
# 26           0.958333           0.833333                1.0
# 27           0.958333           0.833333                1.0
# 28           0.958333           0.833333                1.0
# 29           0.958333           0.833333                1.0
# 30           0.916667           0.833333                1.0
# 31           0.958333           0.833333                1.0
# 32           1.000000           0.875000                1.0
# 33           1.000000           0.875000                1.0
# 34           0.958333           0.833333                1.0
# 35           0.958333           0.833333                1.0
# 36           0.958333           0.833333                1.0
# 37           0.958333           0.833333                1.0
# 38           0.916667           0.833333                1.0
# 39           0.958333           0.833333                1.0
# 40           0.916667           0.833333                1.0
# 41           0.958333           0.833333                1.0
# 42           0.916667           0.833333                1.0
# 43           0.958333           0.833333                1.0
# 44           0.916667           0.833333                1.0
# 45           0.958333           0.833333                1.0
# 46           0.916667           0.833333                1.0
# 47           0.958333           0.833333                1.0
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.958333         0.958333        0.045644                1
# 1            0.958333         0.958333        0.045644                1
# 2            0.958333         0.941667        0.056519               22
# 3            0.958333         0.941667        0.056519               22
# 4            0.958333         0.941667        0.056519               22
# 5            0.958333         0.941667        0.056519               22
# 6            0.958333         0.933333        0.056519               46
# 7            0.958333         0.941667        0.056519               22
# 8            0.958333         0.941667        0.062361               22
# 9            0.958333         0.950000        0.061237                7
# 10           0.958333         0.941667        0.062361               22
# 11           0.958333         0.950000        0.061237                7
# 12           0.958333         0.941667        0.062361               22
# 13           0.958333         0.950000        0.061237                7
# 14           0.958333         0.941667        0.062361               22
# 15           0.958333         0.950000        0.061237                7
# 16           0.958333         0.958333        0.045644                1
# 17           0.958333         0.958333        0.045644                1
# 18           0.958333         0.941667        0.056519               22
# 19           0.958333         0.941667        0.056519               22
# 20           0.958333         0.941667        0.056519               22
# 21           0.958333         0.941667        0.056519               22
# 22           0.958333         0.941667        0.056519               22
# 23           0.958333         0.941667        0.056519               22
# 24           0.958333         0.950000        0.061237                7
# 25           0.958333         0.950000        0.061237                7
# 26           0.958333         0.950000        0.061237                7
# 27           0.958333         0.950000        0.061237                7
# 28           0.958333         0.950000        0.061237                7
# 29           0.958333         0.950000        0.061237                7
# 30           0.916667         0.933333        0.062361               46
# 31           0.958333         0.950000        0.061237                7
# 32           0.958333         0.958333        0.045644                1
# 33           0.958333         0.958333        0.045644                1
# 34           0.958333         0.941667        0.056519               22
# 35           0.958333         0.941667        0.056519               22
# 36           0.958333         0.941667        0.056519               22
# 37           0.958333         0.941667        0.056519               22
# 38           0.958333         0.933333        0.056519               46
# 39           0.958333         0.941667        0.056519               22
# 40           0.958333         0.941667        0.062361               22
# 41           0.958333         0.950000        0.061237                7
# 42           0.958333         0.941667        0.062361               22
# 43           0.958333         0.950000        0.061237                7
# 44           0.958333         0.941667        0.062361               22
# 45           0.958333         0.950000        0.061237                7
# 46           0.958333         0.941667        0.062361               22
# 47           0.958333         0.950000        0.061237                7

# %%
knn_result[['param_metric'	,'param_n_neighbors'	,'param_weights','mean_test_score']]
# Out:
#    param_metric  param_n_neighbors param_weights  mean_test_score
# 0     euclidean                  3       uniform         0.958333
# 1     euclidean                  3      distance         0.958333
# 2     euclidean                  5       uniform         0.941667
# 3     euclidean                  5      distance         0.941667
# 4     euclidean                  7       uniform         0.941667
# 5     euclidean                  7      distance         0.941667
# 6     euclidean                  9       uniform         0.933333
# 7     euclidean                  9      distance         0.941667
# 8     euclidean                 13       uniform         0.941667
# 9     euclidean                 13      distance         0.950000
# 10    euclidean                 15       uniform         0.941667
# 11    euclidean                 15      distance         0.950000
# 12    euclidean                 17       uniform         0.941667
# 13    euclidean                 17      distance         0.950000
# 14    euclidean                 25       uniform         0.941667
# 15    euclidean                 25      distance         0.950000
# 16    manhattan                  3       uniform         0.958333
# 17    manhattan                  3      distance         0.958333
# 18    manhattan                  5       uniform         0.941667
# 19    manhattan                  5      distance         0.941667
# 20    manhattan                  7       uniform         0.941667
# 21    manhattan                  7      distance         0.941667
# 22    manhattan                  9       uniform         0.941667
# 23    manhattan                  9      distance         0.941667
# 24    manhattan                 13       uniform         0.950000
# 25    manhattan                 13      distance         0.950000
# 26    manhattan                 15       uniform         0.950000
# 27    manhattan                 15      distance         0.950000
# 28    manhattan                 17       uniform         0.950000
# 29    manhattan                 17      distance         0.950000
# 30    manhattan                 25       uniform         0.933333
# 31    manhattan                 25      distance         0.950000
# 32    minkowski                  3       uniform         0.958333
# 33    minkowski                  3      distance         0.958333
# 34    minkowski                  5       uniform         0.941667
# 35    minkowski                  5      distance         0.941667
# 36    minkowski                  7       uniform         0.941667
# 37    minkowski                  7      distance         0.941667
# 38    minkowski                  9       uniform         0.933333
# 39    minkowski                  9      distance         0.941667
# 40    minkowski                 13       uniform         0.941667
# 41    minkowski                 13      distance         0.950000
# 42    minkowski                 15       uniform         0.941667
# 43    minkowski                 15      distance         0.950000
# 44    minkowski                 17       uniform         0.941667
# 45    minkowski                 17      distance         0.950000
# 46    minkowski                 25       uniform         0.941667
# 47    minkowski                 25      distance         0.950000

# %% [markdown]
# ## The overfit knn model is rectified.
